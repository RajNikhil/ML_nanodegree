# %% [markdown]
# ## Engineered Features For Customer Product Purchase Trends

# %%
import pandas as pd
import numpy as np

# %%
df_allData = pd.read_pickle('input/all_data.p')

# %%
df_allData.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic-Egg-Whites
# 1         2       28985                  2          1  Michigan-Organic-Kale
# 2         2        9327                  3          0          Garlic-Powder
# 3         2       45918                  4          1         Coconut-Butter
# 4         2       30035                  5          0      Natural-Sweetener
#
#    aisle_id  department_id               aisle  department  user_id eval_set  \
# 0        86             16                eggs  dairy eggs   202279    prior
# 1        83              4    fresh vegetables     produce   202279    prior
# 2       104             13   spices seasonings      pantry   202279    prior
# 3        19             13       oils vinegars      pantry   202279    prior
# 4        17             13  baking ingredients      pantry   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#    SucceedingOrdCnt
# 0                 6
# 1                 6
# 2                 6
# 3                 6
# 4                 6

# %%
df_allDataT = df_allData[df_allData['SucceedingOrdCnt']>1]

# %% [markdown]
# #### Possibility of ordering a Product

# %%
# Count the number of times a product was ordered by a customer.
df_prdCnt = df_allDataT.groupby(['user_id','product_id']).size()

# %%
df_prdCnt.name = 'count'

# %%
df_prdCnt = df_prdCnt.reset_index()
df_prdCnt.head()
# Out:
#    user_id  product_id  count
# 0        1         196      9
# 1        1       10258      8
# 2        1       10326      1
# 3        1       12427      9
# 4        1       13032      2

# %%
# Maximum and Minimum number of times a user placed an order to determine possibility of ordering
maxOrd = df_allDataT.groupby('user_id')['order_number'].max().reset_index()

# %%
maxOrd.columns = ['user_id','maxOrd']

# %%
minPrdOrd = df_allDataT.groupby(['user_id','product_id'])['order_number'].min().reset_index()
minPrdOrd.columns = ['user_id','product_id','minPrdOrd']

# %%
poss = minPrdOrd.merge(maxOrd,on='user_id',how='left')

# %%
poss['possibility'] = poss['maxOrd']-poss['minPrdOrd']+1

# %%
df_comb = df_prdCnt.merge(poss,on=['user_id','product_id'],how='left')

# %%
df_comb['ordPoss'] = df_comb['count']/df_comb['possibility']

# %%
colm = ['user_id','product_id','possibility','ordPoss']

# %%
df_comb.head()
# Out:
#    user_id  product_id  count  minPrdOrd  maxOrd  possibility  ordPoss
# 0        1         196      9          1       9            9     1.00
# 1        1       10258      8          2       9            8     1.00
# 2        1       10326      1          5       9            5     0.20
# 3        1       12427      9          1       9            9     1.00
# 4        1       13032      2          2       9            8     0.25

# %%
df_comb.to_pickle('input/prdOrdPoss.p')

# %% [markdown]
# #### Products Frequency By Customer

# %%
# Calculate average, minimum, maximum, median and standard deviation a product is ordered by a user.
orderSze = df_allDataT.groupby('order_id').size().to_frame()

# %%
orderSze.columns = ['orderSze']

# %%
orderSze.reset_index(inplace=True)

# %%
orderSze = orderSze.merge(df_allDataT[['order_id','user_id','product_id']])

# %%
df = df_allDataT.sort_values(['user_id','product_id']).drop_duplicates(['user_id','product_id'])[['user_id','product_id']]

# %%
df = df.set_index(['user_id','product_id'])

# %%
df_grp = orderSze.groupby(['user_id','product_id'])

# %%
df_grp.head()
# Out:
#           order_id  orderSze  user_id  product_id
# 0                2         9   202279       33120
# 1                2         9   202279       28985
# 2                2         9   202279        9327
# 3                2         9   202279       45918
# 4                2         9   202279       30035
# 5                2         9   202279       17794
# 6                2         9   202279       40141
# 7                2         9   202279        1819
# 8                2         9   202279       43668
# 9                3         8   205970       33754
# 10               3         8   205970       24838
# 11               3         8   205970       17704
# 12               3         8   205970       21903
# 13               3         8   205970       17668
# 14               3         8   205970       46667
# 15               3         8   205970       17461
# 16               3         8   205970       32665
# 17               4        13   178520       46842
# 18               4        13   178520       26434
# 19               4        13   178520       39758
# 20               4        13   178520       27761
# 21               4        13   178520       10054
# 22               4        13   178520       21351
# 23               4        13   178520       22598
# 24               4        13   178520       34862
# 25               4        13   178520       40285
# 26               4        13   178520       17616
# 27               4        13   178520       25146
# 28               4        13   178520       32645
# 29               4        13   178520       41276
# ...            ...       ...      ...         ...
# 29524390   3421077         4   107102       26940
# 29524394   3421078         9    70170       38656
# 29524395   3421078         9    70170       48577
# 29524397   3421078         9    70170       33750
# 29524398   3421078         9    70170       41844
# 29524400   3421078         9    70170       14553
# 29524401   3421079         1   108687       30136
# 29524410   3421080         9    52726       38061
# 29524411   3421081         7   117076       38185
# 29524412   3421081         7   117076       12218
# 29524413   3421081         7   117076       32299
# 29524414   3421081         7   117076        3060
# 29524415   3421081         7   117076       20539
# 29524416   3421081         7   117076       35221
# 29524417   3421081         7   117076       12861
# 29524418   3421082         7   175185       17279
# 29524419   3421082         7   175185       12738
# 29524420   3421082         7   175185       16797
# 29524421   3421082         7   175185       43352
# 29524422   3421082         7   175185       32700
# 29524423   3421082         7   175185       12023
# 29524424   3421082         7   175185       47941
# 29524425   3421083        10    25247        7854
# 29524426   3421083        10    25247       45309
# 29524427   3421083        10    25247       21162
# 29524428   3421083        10    25247       18176
# 29524429   3421083        10    25247       35211
# 29524430   3421083        10    25247       39678
# 29524431   3421083        10    25247       11352
# 29524432   3421083        10    25247        4600
#
# [22976716 rows x 4 columns]

# %%
df['userItem_Freq_min'] = df_grp['orderSze'].min()

# %%
df['userItem_Freq_max'] = df_grp['orderSze'].max()

# %%
df['userItem_Freq_avg'] = df_grp['orderSze'].mean()

# %%
df['userItem_Freq_median'] = df_grp['orderSze'].median()

# %%
df['userItem_Freq_std'] = df_grp['orderSze'].std()

# %%
df.reset_index(inplace=True)

# %%
# Calculate order size by user
userOrderSze = orderSze.groupby(['user_id'])['orderSze'].min().to_frame()

# %%
userOrderSze.columns = ['userOrderSzeMin']

# %%
userOrderSze['userOrderSzeMax']=orderSze.groupby(['user_id'])['orderSze'].max()

# %%
userOrderSze.reset_index(inplace=True)

# %%
df.head()
# Out:
#    user_id  product_id  userItem_Freq_min  userItem_Freq_max  \
# 0        1         196                  4                  8
# 1        1       10258                  4                  8
# 2        1       10326                  8                  8
# 3        1       12427                  4                  8
# 4        1       13032                  5                  6
#
#    userItem_Freq_avg  userItem_Freq_median  userItem_Freq_std
# 0           5.555556                   5.0           1.130388
# 1           5.625000                   5.5           1.187735
# 2           8.000000                   8.0                NaN
# 3           5.555556                   5.0           1.130388
# 4           5.500000                   5.5           0.707107

# %%
df = df.merge(userOrderSze,on='user_id',how='left')

# %%
#Calculate co-occurance of order size and item ordered
df['useritem_cooccur-min-min'] = df['userOrderSzeMin']  - df['userItem_Freq_min']
df['useritem_cooccur-max-min'] = df['userItem_Freq_max'] - df['userItem_Freq_min']
df['useritem_cooccur-max-max'] = df['userOrderSzeMax'] - df['userItem_Freq_max']

# %%
df.drop(['userOrderSzeMin','userOrderSzeMax'],axis=1,inplace=True)

# %%
df.to_pickle('input/ProdFreqCust.p')

# %% [markdown]
# #### Total Purchases

# %%
orders = pd.read_csv('orders.csv',usecols=['order_id','user_id','order_number'])

# %%
label = pd.read_pickle('input/label.p')

# %%
label.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0   2550362         196                  1          1                   Soda
# 1   2550362       10258                  6          1             Pistachios
# 2   2550362       10326                  5          0    Organic-Fuji-Apples
# 3   2550362       12427                  9          1    Original-Beef-Jerky
# 4   2550362       13032                  8          1  Cinnamon-Toast-Crunch
#
#    aisle_id  department_id                   aisle department  user_id  \
# 0        77              7             soft drinks  beverages        1
# 1       117             19  nuts seeds dried fruit     snacks        1
# 2        24              4            fresh fruits    produce        1
# 3        23             19           popcorn jerky     snacks        1
# 4       121             14                  cereal  breakfast        1
#
#   eval_set  order_number  order_dow  order_hour_of_day  \
# 0    prior            10          4                  8
# 1    prior            10          4                  8
# 2    prior             5          4                 15
# 3    prior            10          4                  8
# 4    prior            10          4                  8
#
#    days_since_prior_order  SucceedingOrdCnt      key
# 0                    30.0                 1    1 196
# 1                    30.0                 1  1 10258
# 2                    28.0                 6  1 10326
# 3                    30.0                 1  1 12427
# 4                    30.0                 1  1 13032

# %%
df=label.merge(orders,on=['order_id','user_id'],how='left')

# %%
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0   2550362         196                  1          1                   Soda
# 1   2550362       10258                  6          1             Pistachios
# 2   2550362       10326                  5          0    Organic-Fuji-Apples
# 3   2550362       12427                  9          1    Original-Beef-Jerky
# 4   2550362       13032                  8          1  Cinnamon-Toast-Crunch
#
#    aisle_id  department_id                   aisle department  user_id  \
# 0        77              7             soft drinks  beverages        1
# 1       117             19  nuts seeds dried fruit     snacks        1
# 2        24              4            fresh fruits    produce        1
# 3        23             19           popcorn jerky     snacks        1
# 4       121             14                  cereal  breakfast        1
#
#   eval_set  order_number_x  order_dow  order_hour_of_day  \
# 0    prior              10          4                  8
# 1    prior              10          4                  8
# 2    prior               5          4                 15
# 3    prior              10          4                  8
# 4    prior              10          4                  8
#
#    days_since_prior_order  SucceedingOrdCnt      key  order_number_y
# 0                    30.0                 1    1 196              10
# 1                    30.0                 1  1 10258              10
# 2                    28.0                 6  1 10326              10
# 3                    30.0                 1  1 12427              10
# 4                    30.0                 1  1 13032              10

# %%
# Calculate total number of purchases made by a customer who has made more than 1 purchase
total_buy = df_allData[df_allData['SucceedingOrdCnt']>1].groupby(['user_id','product_id']).size().reset_index()

# %%
total_buy.columns=['user_id','product_id','total_buy']

# %%
df=df.merge(total_buy,on=['user_id','product_id'],how='left')

# %%
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0   2550362         196                  1          1                   Soda
# 1   2550362       10258                  6          1             Pistachios
# 2   2550362       10326                  5          0    Organic-Fuji-Apples
# 3   2550362       12427                  9          1    Original-Beef-Jerky
# 4   2550362       13032                  8          1  Cinnamon-Toast-Crunch
#
#    aisle_id  department_id                   aisle department  user_id  \
# 0        77              7             soft drinks  beverages        1
# 1       117             19  nuts seeds dried fruit     snacks        1
# 2        24              4            fresh fruits    produce        1
# 3        23             19           popcorn jerky     snacks        1
# 4       121             14                  cereal  breakfast        1
#
#   eval_set  order_number_x  order_dow  order_hour_of_day  \
# 0    prior              10          4                  8
# 1    prior              10          4                  8
# 2    prior               5          4                 15
# 3    prior              10          4                  8
# 4    prior              10          4                  8
#
#    days_since_prior_order  SucceedingOrdCnt      key  order_number_y  \
# 0                    30.0                 1    1 196              10
# 1                    30.0                 1  1 10258              10
# 2                    28.0                 6  1 10326              10
# 3                    30.0                 1  1 12427              10
# 4                    30.0                 1  1 13032              10
#
#    total_buy
# 0          9
# 1          8
# 2          1
# 3          9
# 4          2

# %%
df['total_buy_ratio']=df.total_buy/(df.order_number_x-1)

# %%
col = ['user_id','order_id','product_id','total_buy','total_buy_ratio']

# %%
df[col].to_pickle('input/totalbuys.p')
